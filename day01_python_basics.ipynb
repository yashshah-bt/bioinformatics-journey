# %%
#recieving input

input("what is your name?")
print("hi" + name)


#ask two questions: person's name and favorite colour. then, print a mesage like "mosh like blue"
name = input("what is your name")
favourite_colour = input("what is your favourite colour")
print(name + " likes " + favourite_colour)
# Out:
# what is your name?yash
# hiyash
# what is your nameyash
# what is your favourite colourblack
# yash likes black

# %%
#variable
price = 10
price = 20
rating = 4.9
name = "yash"
is_published = True

#we check in a patient named john smith. he's 20 years old and is a new patient
name = "john smith"
age = 20
is_new = True

# %%
#basics
print("yash kumar shah")
print("o----")
print(' ]]]]')
print("*" * 10)
